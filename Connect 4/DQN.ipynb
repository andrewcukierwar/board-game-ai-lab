# %%
from connect4 import Connect4
from agents.human import Human
from agents.random_agent import RandomAgent
from agents.negamax_agent import NegamaxAgent

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, output_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
from collections import deque
import numpy as np
import random

class DQNAgent:
    def __init__(self, env):
        self.env = env
        self.memory = deque(maxlen=10000)
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        self.batch_size = 64
        self.model = DQN(input_dim=42, output_dim=7)  # 6x7 board flattened
        self.target_model = DQN(input_dim=42, output_dim=7)
        self.update_target_model()
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)

    def convert_board_to_numeric_and_flatten(self, board):
        conversion = {'X': 1, 'O': -1, ' ': 0}
        numeric_board = np.array([[conversion[cell] for cell in row] for row in board])
        return numeric_board.flatten()

    def convert_board_to_numeric(self, board):
        conversion = {'X': 1, 'O': -1, ' ': 0}
        numeric_board = np.array([conversion[cell] for cell in board])
        return numeric_board

    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def act(self, state):
        valid_moves = self.env.get_valid_moves()
        if not valid_moves: # If there are no valid moves, return -1
            return -1
        if np.random.rand() <= self.epsilon:
            return random.choice(valid_moves)
        state = self.convert_board_to_numeric(state)  # Convert board to numeric
        state = torch.FloatTensor(state).unsqueeze(0)
        q_values = self.model(state)
        valid_moves = self.env.get_valid_moves()
        valid_q_values = [q_values[0][move].item() for move in valid_moves]
        best_move = valid_moves[valid_q_values.index(max(valid_q_values))]
        return best_move

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in minibatch:
            state = self.convert_board_to_numeric(state)  # Convert board to numeric
            next_state = self.convert_board_to_numeric(next_state)  # Convert board to numeric
            
            state = torch.FloatTensor(state).unsqueeze(0)
            next_state = torch.FloatTensor(next_state).unsqueeze(0)
            target = reward
            if not done:
                target += self.gamma * torch.max(self.target_model(next_state)).item()
            target_f = self.model(state)
            target_f[0][action] = target
            self.optimizer.zero_grad()
            loss = F.mse_loss(target_f, self.model(state))
            loss.backward()
            self.optimizer.step()
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def train(self, episodes):
        for e in range(episodes):
            self.env = Connect4()
            state = self.env.board.flatten()
            done = False
            while not done:
                action = self.act(state)
                next_state, reward, done, _ = self.env.step(action)
                next_state = next_state.flatten()
                self.remember(state, action, reward, next_state, done)
                state = next_state
                self.replay()
            # print(state.reshape(6,7))
            self.update_target_model()
            print(f"Episode {e+1}/{episodes} - Epsilon: {self.epsilon:.4f}")
            print(state.reshape(6,7))

# %%
env = Connect4()
agent = DQNAgent(env)
agent.train(episodes=1000)
# Out:
# Episode 1/1000 - Epsilon: 1.0000
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['O' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['X' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['X' ' ' ' ' 'X' ' ' ' ' 'X']
#  ['O' 'X' ' ' 'O' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'X' 'O']]
# Episode 2/1000 - Epsilon: 1.0000
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['O' ' ' 'X' ' ' ' ' ' ' ' ']
#  ['X' 'O' 'X' ' ' ' ' ' ' ' ']
#  ['O' 'X' 'O' 'O' ' ' 'X' ' ']
#  ['O' 'X' 'X' 'O' 'X' 'O' ' ']]
# Episode 3/1000 - Epsilon: 1.0000
# [[' ' ' ' 'O' ' ' ' ' ' ' 'X']
#  [' ' ' ' 'O' ' ' ' ' 'O' 'X']
#  [' ' 'X' 'O' ' ' ' ' 'O' 'X']
#  ['X' 'X' 'O' 'X' ' ' 'X' 'O']
#  ['O' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'O' 'O' 'X']]
# Episode 4/1000 - Epsilon: 0.8604
# [['X' ' ' ' ' ' ' 'O' ' ' 'X']
#  ['O' ' ' ' ' ' ' 'X' ' ' 'X']
#  ['X' 'O' ' ' 'O' 'O' ' ' 'X']
#  ['O' 'X' ' ' 'X' 'O' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'X' 'X' 'O']
#  ['O' 'X' 'O' 'O' 'X' 'X' 'X']]
# Episode 5/1000 - Epsilon: 0.7590
# [[' ' ' ' ' ' 'X' ' ' ' ' ' ']
#  [' ' ' ' ' ' 'O' ' ' ' ' ' ']
#  ['O' 'O' ' ' 'O' ' ' ' ' 'X']
#  ['X' 'X' ' ' 'X' 'X' ' ' 'X']
#  ['O' 'X' 'O' 'O' 'X' 'O' 'X']
#  ['O' 'O' 'X' 'O' 'O' 'X' 'X']]
# Episode 6/1000 - Epsilon: 0.6832
# [['O' ' ' ' ' ' ' ' ' ' ' ' ']
#  ['X' 'O' ' ' ' ' ' ' ' ' ' ']
#  ['O' 'X' ' ' ' ' ' ' ' ' ' ']
#  ['X' 'X' 'X' ' ' ' ' 'O' ' ']
#  ['X' 'O' 'X' 'X' 'O' 'O' ' ']
#  ['X' 'O' 'X' 'O' 'X' 'O' ' ']]
# Episode 7/1000 - Epsilon: 0.6274
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'X' ' ' 'X' ' ' ' ']
#  [' ' ' ' 'X' 'O' 'O' ' ' 'X']
#  [' ' 'O' 'X' 'O' 'O' ' ' 'X']
#  [' ' 'X' 'X' 'O' 'X' 'O' 'O']]
# Episode 8/1000 - Epsilon: 0.5997
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' 'O' ' ' ' ' ' ' ' ' ' ']
#  [' ' 'O' ' ' ' ' ' ' ' ' ' ']
#  [' ' 'X' ' ' ' ' ' ' ' ' ' ']
#  ['X' 'X' 'X' 'X' 'O' ' ' 'O']]
# Episode 9/1000 - Epsilon: 0.5134
# [[' ' 'O' 'O' 'X' ' ' ' ' 'O']
#  [' ' 'O' 'O' 'X' ' ' ' ' 'O']
#  ['X' 'X' 'X' 'O' ' ' ' ' 'O']
#  ['X' 'X' 'O' 'O' 'X' ' ' 'X']
#  ['O' 'X' 'X' 'X' 'O' ' ' 'O']
#  ['X' 'O' 'X' 'X' 'X' ' ' 'O']]
# Episode 10/1000 - Epsilon: 0.4286
# [['O' 'X' 'X' 'O' ' ' 'X' ' ']
#  ['X' 'O' 'X' 'X' ' ' 'O' ' ']
#  ['X' 'O' 'O' 'O' ' ' 'X' 'X']
#  ['O' 'O' 'X' 'X' ' ' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'O' 'O' 'X']]
# Episode 11/1000 - Epsilon: 0.3820
# [[' ' ' ' ' ' 'X' ' ' ' ' ' ']
#  [' ' 'O' ' ' 'O' ' ' ' ' ' ']
#  [' ' 'O' ' ' 'O' ' ' ' ' 'X']
#  [' ' 'X' ' ' 'X' 'O' 'X' 'X']
#  [' ' 'O' ' ' 'X' 'O' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'X']]
# Episode 12/1000 - Epsilon: 0.3651
# [[' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' ' ' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'X' ' ' ' ' ' ' ' ']
#  [' ' ' ' 'X' ' ' ' ' ' ' ' ']
#  [' ' 'O' 'X' 'O' ' ' ' ' ' ']
#  [' ' 'X' 'X' 'O' 'O' ' ' ' ']]
# Episode 13/1000 - Epsilon: 0.3286
# [[' ' ' ' ' ' 'X' ' ' ' ' ' ']
#  [' ' ' ' ' ' 'O' ' ' ' ' ' ']
#  ['O' ' ' ' ' 'X' ' ' ' ' 'O']
#  ['O' 'X' 'X' 'X' ' ' ' ' 'X']
#  ['O' 'X' 'O' 'X' ' ' ' ' 'O']
#  ['X' 'O' 'X' 'O' ' ' 'X' 'O']]
# Episode 14/1000 - Epsilon: 0.2785
# [[' ' 'O' ' ' 'X' 'O' ' ' ' ']
#  [' ' 'X' 'O' 'O' 'X' ' ' ' ']
#  ['X' 'X' 'X' 'X' 'O' 'O' ' ']
#  ['O' 'X' 'O' 'O' 'X' 'O' ' ']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'X' 'X' 'X']]
# Episode 15/1000 - Epsilon: 0.2385
# [['O' 'X' ' ' 'O' ' ' ' ' 'X']
#  ['O' 'O' ' ' 'O' ' ' ' ' 'O']
#  ['X' 'X' ' ' 'X' 'X' ' ' 'O']
#  ['O' 'O' 'O' 'X' 'X' ' ' 'O']
#  ['X' 'X' 'O' 'O' 'X' ' ' 'X']
#  ['X' 'X' 'O' 'X' 'X' ' ' 'O']]
# Episode 16/1000 - Epsilon: 0.2093
# [[' ' ' ' ' ' ' ' ' ' 'X' ' ']
#  [' ' ' ' ' ' ' ' ' ' 'O' 'X']
#  [' ' 'O' 'X' 'O' ' ' 'X' 'O']
#  [' ' 'O' 'O' 'X' ' ' 'X' 'O']
#  ['X' 'O' 'X' 'O' ' ' 'X' 'X']
#  ['X' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 17/1000 - Epsilon: 0.1875
# [[' ' 'X' ' ' 'O' ' ' ' ' ' ']
#  [' ' 'X' ' ' 'X' 'O' ' ' ' ']
#  [' ' 'O' ' ' 'X' 'O' ' ' ' ']
#  [' ' 'X' ' ' 'O' 'O' ' ' ' ']
#  [' ' 'O' ' ' 'X' 'O' ' ' 'X']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']]
# Episode 18/1000 - Epsilon: 0.1670
# [[' ' ' ' ' ' 'X' ' ' ' ' 'O']
#  [' ' ' ' ' ' 'O' ' ' ' ' 'X']
#  ['X' ' ' ' ' 'O' ' ' ' ' 'O']
#  ['X' 'O' ' ' 'X' ' ' ' ' 'X']
#  ['X' 'X' ' ' 'X' 'O' ' ' 'O']
#  ['X' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 19/1000 - Epsilon: 0.1388
# [['X' 'O' ' ' 'X' ' ' ' ' 'X']
#  ['O' 'X' 'O' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'O' 'X' ' ' 'O' 'X']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'O']
#  ['X' 'X' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'O' 'X' 'X']]
# Episode 20/1000 - Epsilon: 0.1170
# [[' ' 'X' 'X' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'O' 'O' ' ' 'X' 'O']
#  ['X' 'X' 'X' 'O' ' ' 'O' 'O']
#  ['X' 'O' 'O' 'O' ' ' 'X' 'X']
#  ['O' 'X' 'X' 'X' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'X']]
# Episode 21/1000 - Epsilon: 0.1022
# [[' ' 'O' 'O' ' ' ' ' ' ' 'O']
#  [' ' 'X' 'X' ' ' ' ' ' ' 'X']
#  [' ' 'O' 'O' ' ' ' ' ' ' 'O']
#  ['X' 'X' 'X' ' ' ' ' 'O' 'X']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['X' 'X' 'X' 'X' 'O' 'X' 'O']]
# Episode 22/1000 - Epsilon: 0.0862
# [['O' 'X' ' ' 'X' ' ' 'X' 'O']
#  ['X' 'X' ' ' 'O' ' ' 'O' 'X']
#  ['X' 'O' ' ' 'X' ' ' 'X' 'O']
#  ['O' 'O' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'O' ' ' 'X' 'O']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'X']]
# Episode 23/1000 - Epsilon: 0.0709
# [['O' 'O' 'O' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'O' 'O']
#  ['X' 'O' 'O' 'O' ' ' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'X' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 24/1000 - Epsilon: 0.0589
# [['X' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['O' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'X' 'O' 'O' ' ' 'X' 'X']
#  ['O' 'O' 'X' 'X' ' ' 'O' 'O']
#  ['X' 'X' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 25/1000 - Epsilon: 0.0497
# [['X' 'X' 'X' ' ' ' ' 'O' 'X']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'X']]
# Episode 26/1000 - Epsilon: 0.0415
# [['O' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['O' 'X' 'X' 'X' ' ' 'X' 'O']
#  ['X' 'O' 'X' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'O' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'O' 'O']
#  ['X' 'O' 'X' 'O' ' ' 'X' 'X']]
# Episode 27/1000 - Epsilon: 0.0366
# [[' ' ' ' ' ' ' ' ' ' 'O' 'X']
#  [' ' ' ' 'O' ' ' ' ' 'X' 'X']
#  [' ' ' ' 'X' ' ' ' ' 'X' 'X']
#  [' ' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['O' 'O' 'X' 'X' ' ' 'X' 'O']
#  ['X' 'X' 'O' 'O' ' ' 'O' 'X']]
# Episode 28/1000 - Epsilon: 0.0305
# [['X' 'O' 'O' ' ' ' ' 'O' 'O']
#  ['X' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['O' 'O' 'O' 'O' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'O' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'X']]
# Episode 29/1000 - Epsilon: 0.0275
# [['O' 'X' ' ' ' ' ' ' ' ' ' ']
#  ['X' 'X' ' ' ' ' ' ' ' ' ' ']
#  ['O' 'X' ' ' 'X' ' ' ' ' ' ']
#  ['O' 'X' ' ' 'O' ' ' ' ' 'X']
#  ['X' 'O' 'O' 'O' ' ' ' ' 'O']
#  ['O' 'X' 'X' 'X' ' ' ' ' 'O']]
# Episode 30/1000 - Epsilon: 0.0237
# [['X' 'O' ' ' 'X' ' ' ' ' 'X']
#  ['X' 'X' ' ' 'O' ' ' ' ' 'O']
#  ['O' 'O' 'O' 'O' ' ' ' ' 'X']
#  ['X' 'O' 'X' 'X' ' ' ' ' 'O']
#  ['O' 'X' 'O' 'O' 'X' ' ' 'X']
#  ['X' 'O' 'X' 'X' 'O' ' ' 'O']]
# Episode 31/1000 - Epsilon: 0.0211
# [['O' ' ' ' ' ' ' ' ' 'X' 'O']
#  ['X' ' ' ' ' ' ' ' ' 'O' 'X']
#  ['O' ' ' ' ' ' ' ' ' 'X' 'O']
#  ['X' ' ' ' ' 'O' ' ' 'O' 'X']
#  ['O' ' ' ' ' 'X' 'X' 'X' 'X']
#  ['X' ' ' ' ' 'O' 'O' 'X' 'O']]
# Episode 32/1000 - Epsilon: 0.0177
# [['O' ' ' 'O' 'O' ' ' 'X' 'X']
#  ['X' 'X' 'X' 'X' ' ' 'O' 'X']
#  ['X' 'X' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'X' 'O' 'O' ' ' 'O' 'X']
#  ['O' 'O' 'X' 'O' ' ' 'O' 'X']]
# Episode 33/1000 - Epsilon: 0.0162
# [['X' 'O' ' ' ' ' ' ' ' ' ' ']
#  ['O' 'X' ' ' ' ' ' ' ' ' ' ']
#  ['X' 'O' ' ' ' ' ' ' ' ' 'X']
#  ['O' 'O' ' ' ' ' ' ' ' ' 'X']
#  ['X' 'X' ' ' ' ' ' ' ' ' 'X']
#  ['O' 'O' 'O' ' ' ' ' ' ' 'X']]
# Episode 34/1000 - Epsilon: 0.0137
# [['O' ' ' 'O' 'O' ' ' 'X' 'X']
#  ['X' ' ' 'X' 'X' ' ' 'O' 'O']
#  ['O' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['X' 'X' 'X' 'O' ' ' 'X' 'O']
#  ['X' 'O' 'O' 'X' ' ' 'O' 'X']
#  ['O' 'X' 'X' 'O' ' ' 'X' 'X']]
# Episode 35/1000 - Epsilon: 0.0121
# [['X' 'O' ' ' 'X' ' ' ' ' ' ']
#  ['O' 'O' ' ' 'O' ' ' ' ' ' ']
#  ['X' 'O' ' ' 'X' 'X' ' ' ' ']
#  ['X' 'X' ' ' 'X' 'O' ' ' ' ']
#  ['O' 'O' 'X' 'X' 'O' ' ' ' ']
#  ['X' 'X' 'X' 'O' 'O' ' ' 'O']]
# Episode 36/1000 - Epsilon: 0.0102
# [['O' ' ' 'O' 'O' ' ' 'X' 'O']
#  ['X' ' ' 'X' 'X' ' ' 'O' 'X']
#  ['O' 'O' 'O' 'O' ' ' 'X' 'O']
#  ['X' 'X' 'X' 'O' ' ' 'O' 'X']
#  ['O' 'O' 'O' 'X' ' ' 'X' 'X']
#  ['X' 'X' 'O' 'O' ' ' 'X' 'X']]
# Episode 37/1000 - Epsilon: 0.0100
# [['O' ' ' ' ' 'X' ' ' 'X' 'O']
#  ['X' ' ' ' ' 'O' ' ' 'O' 'X']
#  ['O' ' ' ' ' 'O' ' ' 'X' 'O']
#  ['X' ' ' ' ' 'X' 'X' 'X' 'X']
#  ['O' ' ' ' ' 'O' 'X' 'O' 'O']
#  ['X' ' ' ' ' 'X' 'O' 'X' 'O']]
# Episode 38/1000 - Epsilon: 0.0100
# [['X' 'O' ' ' 'X' ' ' 'O' 'O']
#  ['O' 'X' ' ' 'O' ' ' 'X' 'X']
#  ['X' 'O' ' ' 'X' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'O' ' ' 'X' 'X']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'O' 'O' 'X' 'X']]
# Episode 39/1000 - Epsilon: 0.0100
# [['X' ' ' ' ' ' ' ' ' 'X' ' ']
#  ['X' ' ' ' ' ' ' ' ' 'O' ' ']
#  ['X' 'O' ' ' ' ' ' ' 'X' 'O']
#  ['O' 'O' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'X' 'O']
#  ['X' 'O' 'O' 'X' ' ' 'X' 'X']]
# Episode 40/1000 - Epsilon: 0.0100
# [[' ' ' ' ' ' 'X' 'X' 'X' 'O']
#  [' ' ' ' ' ' 'O' 'O' 'O' 'X']
#  ['O' ' ' 'O' 'O' 'X' 'X' 'O']
#  ['O' ' ' 'X' 'X' 'O' 'O' 'X']
#  ['X' ' ' 'X' 'O' 'X' 'X' 'O']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'X']]
# Episode 41/1000 - Epsilon: 0.0100
# [['X' ' ' ' ' 'O' ' ' 'X' 'O']
#  ['O' ' ' ' ' 'O' ' ' 'O' 'X']
#  ['X' ' ' ' ' 'X' 'O' 'X' 'X']
#  ['O' ' ' 'X' 'O' 'X' 'O' 'O']
#  ['X' ' ' 'O' 'O' 'O' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'O']]
# Episode 42/1000 - Epsilon: 0.0100
# [['O' ' ' 'X' 'O' ' ' 'X' 'X']
#  ['X' ' ' 'O' 'O' ' ' 'O' 'O']
#  ['O' ' ' 'X' 'X' ' ' 'X' 'X']
#  ['X' ' ' 'O' 'O' ' ' 'O' 'O']
#  ['X' 'O' 'X' 'O' ' ' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'X' 'O' 'O']]
# Episode 43/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' 'O' 'X' 'O' 'X']
#  ['O' 'X' 'O' 'O' 'O' 'X' 'X']
#  ['X' 'O' 'X' 'X' 'X' 'O' 'O']
#  ['O' 'X' 'O' 'O' 'O' 'X' 'O']]
# Episode 44/1000 - Epsilon: 0.0100
# [['X' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['O' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['X' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['O' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'X']]
# Episode 45/1000 - Epsilon: 0.0100
# [['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' 'X' 'X']]
# Episode 46/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'O' ' ' 'O']
#  ['O' ' ' 'O' 'O' 'X' ' ' 'X']
#  ['O' ' ' 'X' 'X' 'O' ' ' 'O']
#  ['X' ' ' 'O' 'O' 'X' ' ' 'X']
#  ['O' ' ' 'X' 'X' 'O' 'X' 'O']
#  ['X' ' ' 'O' 'O' 'X' 'X' 'X']]
# Episode 47/1000 - Epsilon: 0.0100
# [['X' ' ' ' ' ' ' 'X' ' ' ' ']
#  ['O' ' ' 'X' ' ' 'O' ' ' ' ']
#  ['X' ' ' 'X' 'X' 'X' ' ' ' ']
#  ['O' 'O' 'O' 'O' 'O' ' ' ' ']
#  ['O' 'X' 'X' 'O' 'X' ' ' ' ']
#  ['X' 'O' 'O' 'O' 'X' ' ' ' ']]
# Episode 48/1000 - Epsilon: 0.0100
# [['X' ' ' 'O' 'X' 'O' ' ' 'O']
#  ['O' ' ' 'O' 'X' 'X' ' ' 'X']
#  ['X' ' ' 'X' 'O' 'O' ' ' 'O']
#  ['O' ' ' 'O' 'X' 'O' ' ' 'X']
#  ['X' ' ' 'X' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'O' 'X' 'X' 'X' 'X']]
# Episode 49/1000 - Epsilon: 0.0100
# [['O' 'X' ' ' 'O' ' ' 'O' 'O']
#  ['X' 'O' ' ' 'X' ' ' 'X' 'X']
#  ['O' 'X' ' ' 'X' ' ' 'O' 'O']
#  ['X' 'O' ' ' 'O' ' ' 'X' 'O']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']]
# Episode 50/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' 'X' ' ']
#  ['O' 'X' ' ' 'X' ' ' 'O' ' ']
#  ['O' 'O' ' ' 'O' ' ' 'X' ' ']
#  ['O' 'O' ' ' 'X' ' ' 'O' ' ']
#  ['X' 'X' 'X' 'X' ' ' 'X' ' ']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']]
# Episode 51/1000 - Epsilon: 0.0100
# [['O' ' ' 'O' 'X' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'O' 'X' ' ' 'O']
#  ['X' 'O' 'O' 'X' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'O' 'X' ' ' 'O']
#  ['O' 'O' 'X' 'X' 'O' ' ' 'X']
#  ['X' 'O' 'O' 'O' 'X' 'O' 'O']]
# Episode 52/1000 - Epsilon: 0.0100
# [[' ' ' ' 'O' 'O' 'X' ' ' 'O']
#  [' ' ' ' 'X' 'X' 'X' ' ' 'X']
#  [' ' ' ' 'O' 'O' 'O' ' ' 'O']
#  [' ' ' ' 'O' 'X' 'X' ' ' 'X']
#  [' ' ' ' 'O' 'O' 'O' ' ' 'O']
#  [' ' ' ' 'X' 'X' 'X' 'X' 'X']]
# Episode 53/1000 - Epsilon: 0.0100
# [['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' 'X' 'X']]
# Episode 54/1000 - Epsilon: 0.0100
# [['O' ' ' 'O' 'X' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'O' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'X' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'O' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'X']]
# Episode 55/1000 - Epsilon: 0.0100
# [['X' 'O' ' ' 'O' 'O' ' ' 'X']
#  ['O' 'X' ' ' 'X' 'X' ' ' 'O']
#  ['X' 'O' ' ' 'O' 'O' ' ' 'X']
#  ['O' 'X' ' ' 'X' 'X' ' ' 'O']
#  ['O' 'O' ' ' 'O' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'O']]
# Episode 56/1000 - Epsilon: 0.0100
# [['X' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['O' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['X' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['O' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' 'X' 'X']]
# Episode 57/1000 - Epsilon: 0.0100
# [['X' ' ' ' ' 'O' 'O' ' ' ' ']
#  ['O' ' ' ' ' 'X' 'X' ' ' ' ']
#  ['X' ' ' ' ' 'O' 'O' ' ' ' ']
#  ['O' ' ' ' ' 'X' 'X' ' ' 'O']
#  ['O' ' ' ' ' 'O' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'O']]
# Episode 58/1000 - Epsilon: 0.0100
# [['X' ' ' 'O' 'X' 'X' ' ' 'O']
#  ['O' ' ' 'X' 'O' 'O' ' ' 'X']
#  ['X' ' ' 'O' 'O' 'X' ' ' 'O']
#  ['O' ' ' 'X' 'X' 'O' ' ' 'X']
#  ['O' ' ' 'X' 'O' 'O' ' ' 'O']
#  ['X' 'X' 'O' 'X' 'X' ' ' 'X']]
# Episode 59/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' 'X' ' ' ' ' 'X']
#  ['O' ' ' 'O' 'O' ' ' ' ' 'O']
#  ['X' ' ' 'X' 'X' ' ' ' ' 'X']
#  ['O' 'O' 'O' 'O' 'O' ' ' 'O']
#  ['O' 'X' 'X' 'X' 'O' ' ' 'X']
#  ['X' 'O' 'O' 'X' 'X' ' ' 'O']]
# Episode 60/1000 - Epsilon: 0.0100
# [['O' 'O' ' ' 'X' 'O' ' ' 'X']
#  ['X' 'X' ' ' 'O' 'X' ' ' 'O']
#  ['X' 'O' ' ' 'O' 'O' ' ' 'X']
#  ['O' 'X' ' ' 'X' 'X' ' ' 'O']
#  ['O' 'O' ' ' 'O' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'O']]
# Episode 61/1000 - Epsilon: 0.0100
# [['O' ' ' ' ' 'X' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'O' 'X' ' ' 'X']
#  ['X' ' ' 'O' 'X' 'O' ' ' 'O']
#  ['O' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' 'X' 'O']
#  ['X' ' ' 'O' 'X' 'X' 'X' 'O']]
# Episode 62/1000 - Epsilon: 0.0100
# [['O' 'O' ' ' 'O' 'X' ' ' 'O']
#  ['O' 'X' ' ' 'X' 'O' ' ' 'X']
#  ['X' 'O' ' ' 'O' 'X' ' ' 'X']
#  ['O' 'X' ' ' 'X' 'O' ' ' 'O']
#  ['O' 'O' ' ' 'O' 'O' ' ' 'X']
#  ['X' 'X' ' ' 'X' 'X' 'X' 'X']]
# Episode 63/1000 - Epsilon: 0.0100
# [['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['O' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['X' 'O' 'O' 'O' 'O' ' ' 'O']
#  ['X' 'X' 'X' 'O' 'X' ' ' 'X']
#  ['O' 'O' 'O' 'X' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'O' 'X' ' ' 'X']]
# Episode 64/1000 - Epsilon: 0.0100
# [['O' ' ' 'O' 'O' 'O' ' ' 'X']
#  ['X' ' ' 'X' 'X' 'X' ' ' 'X']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' ' ' 'X' 'X' 'X' ' ' 'O']
#  ['O' ' ' 'O' 'O' 'O' ' ' 'O']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'X']]
# Episode 65/1000 - Epsilon: 0.0100
# [['O' ' ' 'X' 'O' 'X' 'X' 'O']
#  ['X' ' ' 'X' 'X' 'O' 'O' 'X']
#  ['O' ' ' 'O' 'O' 'X' 'O' 'O']
#  ['X' ' ' 'X' 'X' 'O' 'O' 'X']
#  ['O' 'O' 'O' 'O' 'X' 'X' 'O']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'X']]
# Episode 66/1000 - Epsilon: 0.0100
# [['O' ' ' ' ' 'X' 'X' ' ' 'X']
#  ['O' ' ' ' ' 'O' 'X' ' ' 'O']
#  ['X' ' ' ' ' 'X' 'O' ' ' 'X']
#  ['O' 'X' ' ' 'O' 'X' ' ' 'X']
#  ['O' 'O' 'X' 'O' 'O' ' ' 'X']
#  ['X' 'O' 'O' 'X' 'X' ' ' 'O']]
# Episode 67/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'O' 'O']
#  ['O' 'X' 'O' 'O' 'X' 'X' 'X']]
# Episode 68/1000 - Epsilon: 0.0100
# [['X' 'X' ' ' ' ' 'X' ' ' 'X']
#  ['O' 'O' ' ' 'X' 'O' ' ' 'O']
#  ['X' 'X' ' ' 'O' 'X' ' ' 'X']
#  ['O' 'O' 'O' 'O' 'X' ' ' 'O']
#  ['O' 'X' 'X' 'X' 'O' ' ' 'O']
#  ['X' 'O' 'O' 'O' 'X' ' ' 'X']]
# Episode 69/1000 - Epsilon: 0.0100
# [[' ' ' ' 'O' ' ' 'O' ' ' 'O']
#  [' ' ' ' 'X' ' ' 'X' ' ' 'X']
#  [' ' ' ' 'O' ' ' 'X' ' ' 'O']
#  [' ' ' ' 'X' ' ' 'O' ' ' 'X']
#  [' ' ' ' 'O' ' ' 'O' ' ' 'O']
#  ['O' 'X' 'X' 'X' 'X' ' ' 'X']]
# Episode 70/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'X' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'O' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'X' 'X']]
# Episode 71/1000 - Epsilon: 0.0100
# [['O' ' ' ' ' ' ' ' ' ' ' 'X']
#  ['X' ' ' ' ' ' ' ' ' ' ' 'O']
#  ['O' ' ' ' ' ' ' ' ' ' ' 'X']
#  ['X' ' ' ' ' ' ' 'X' ' ' 'O']
#  ['O' ' ' ' ' ' ' 'O' ' ' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 72/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['O' 'X' 'O' ' ' ' ' 'O' 'O']
#  ['X' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['O' 'X' 'O' 'X' ' ' 'O' 'O']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['O' 'X' 'O' 'O' ' ' 'O' 'O']]
# Episode 73/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' ' ' 'O' 'X']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'X' 'O']]
# Episode 74/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'X' 'O']]
# Episode 75/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'X' 'O']]
# Episode 76/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'O' 'O']]
# Episode 77/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'X' 'O']]
# Episode 78/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'X' 'X' 'X' 'X']
#  ['X' 'X' 'X' 'O' 'O' 'O' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'X' 'O']
#  ['X' 'X' 'X' 'O' 'O' 'O' 'X']
#  ['O' 'X' 'O' 'O' 'X' 'X' 'O']]
# Episode 79/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'X' 'O']]
# Episode 80/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' 'O' 'O' 'O' 'O']
#  ['O' 'X' 'O' 'X' 'X' 'X' 'O']]
# Episode 81/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' 'O' 'O' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'O' 'O' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'O' 'O']]
# Episode 82/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'X']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'X']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'O']
#  ['O' 'X' 'O' 'X' 'X' 'X' 'O']]
# Episode 83/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'O' 'O']]
# Episode 84/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'X']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'X']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 85/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'X' 'O']]
# Episode 86/1000 - Epsilon: 0.0100
# [['O' 'X' 'O' 'O' ' ' 'X' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'O' 'O']
#  ['O' 'X' 'O' 'O' ' ' 'X' 'O']
#  ['X' 'O' 'X' 'X' ' ' 'O' 'X']
#  ['O' 'X' 'O' 'O' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'X' 'X' 'O' 'X']]
# Episode 87/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'X' 'O']]
# Episode 88/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'X' 'O']]
# Episode 89/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'O' 'X' 'O' 'X' 'O']]
# Episode 90/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'O' 'O']]
# Episode 91/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 92/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 93/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 94/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 95/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 96/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 97/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' 'X' 'X' 'O' 'O']]
# Episode 98/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'O' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['O' 'X' 'O' 'X' ' ' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 99/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']]
# Episode 100/1000 - Epsilon: 0.0100
# [[' ' 'X' ' ' ' ' ' ' ' ' ' ']
#  [' ' 'O' 'X' ' ' ' ' ' ' ' ']
#  [' ' 'X' 'O' 'X' ' ' ' ' ' ']
#  [' ' 'O' 'X' 'O' ' ' ' ' ' ']
#  ['O' 'X' 'X' 'X' ' ' ' ' ' ']
#  ['X' 'O' 'O' 'O' ' ' ' ' ' ']]
# Episode 101/1000 - Epsilon: 0.0100
# [['O' 'X' 'X' 'O' 'O' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'X']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'O']]
# Episode 102/1000 - Epsilon: 0.0100
# [['O' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'O' 'O' 'X' 'O' 'O' 'O']
#  ['O' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['X' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['O' 'X' 'X' 'O' 'X' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'O' 'X' 'O']]
# Episode 103/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['O' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['X' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['O' 'O' 'O' ' ' ' ' 'X' 'O']
#  ['X' 'X' 'X' ' ' ' ' 'O' 'O']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'X']]
# Episode 104/1000 - Epsilon: 0.0100
# [['O' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']
#  ['X' 'X' 'O' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'X' 'X' 'O' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'X' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'O' 'X' 'O']]
# Episode 105/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'X' 'O' 'O' 'O']]
# Episode 106/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'X']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'X']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'O']]
# Episode 107/1000 - Epsilon: 0.0100
# [['O' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' 'X' 'X' 'X' 'X']
#  ['X' 'X' 'X' 'O' 'O' 'O' 'X']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'O']]
# Episode 108/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' ' ' 'O' 'X']
#  ['O' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['X' 'X' 'X' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'O' ' ' ' ' 'O' 'O']
#  ['O' 'X' 'X' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']]
# Episode 109/1000 - Epsilon: 0.0100
# [[' ' 'X' 'O' ' ' ' ' 'O' 'X']
#  [' ' 'O' 'X' ' ' ' ' 'X' 'O']
#  [' ' 'X' 'O' 'X' ' ' 'O' 'X']
#  ['O' 'O' 'X' 'O' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'O' 'X']
#  ['X' 'O' 'O' 'X' ' ' 'X' 'O']]
# Episode 110/1000 - Epsilon: 0.0100
# [[' ' 'X' 'X' 'O' ' ' 'X' ' ']
#  [' ' 'O' 'O' 'X' ' ' 'X' ' ']
#  [' ' 'X' 'O' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'X' 'X' 'X' 'X' ' ']
#  ['O' 'X' 'X' 'O' 'O' 'O' ' ']
#  ['X' 'O' 'O' 'O' 'X' 'X' ' ']]
# Episode 111/1000 - Epsilon: 0.0100
# [['O' 'O' 'O' ' ' ' ' 'O' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'X' 'O']
#  ['O' 'X' 'O' ' ' ' ' 'O' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'X' 'O' 'X' 'O']]
# Episode 112/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 113/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'X' 'X']]
# Episode 114/1000 - Epsilon: 0.0100
# [[' ' 'O' 'X' 'O' ' ' 'X' 'X']
#  [' ' 'O' 'O' 'X' ' ' 'O' 'X']
#  [' ' 'X' 'X' 'O' ' ' 'X' 'O']
#  ['O' 'O' 'O' 'O' ' ' 'X' 'X']
#  ['O' 'X' 'O' 'X' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'X' 'X']]
# Episode 115/1000 - Epsilon: 0.0100
# [['O' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'O' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'O' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'X']]
# Episode 116/1000 - Epsilon: 0.0100
# [['O' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'O' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'O']]
# Episode 117/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' 'O' 'O']
#  [' ' 'O' ' ' 'X' ' ' 'X' 'X']
#  [' ' 'X' 'X' 'O' ' ' 'O' 'O']
#  [' ' 'O' 'X' 'X' ' ' 'X' 'O']
#  [' ' 'X' 'X' 'O' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'O']]
# Episode 118/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 119/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 120/1000 - Epsilon: 0.0100
# [['O' 'O' 'X' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'X' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 121/1000 - Epsilon: 0.0100
# [[' ' 'O' 'X' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'O' 'X' ' ' 'X' ' ']
#  [' ' 'X' 'X' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'O' 'X' ' ' 'X' ' ']
#  [' ' 'X' 'X' 'O' 'X' 'O' ' ']
#  ['X' 'O' 'X' 'X' 'O' 'X' ' ']]
# Episode 122/1000 - Epsilon: 0.0100
# [[' ' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['O' 'X' 'X' 'X' ' ' 'X' 'O']
#  ['X' 'X' 'X' 'O' ' ' 'O' 'X']
#  ['O' 'O' 'O' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'X' 'O' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'X' 'O' 'X' 'X']]
# Episode 123/1000 - Epsilon: 0.0100
# [[' ' 'O' 'O' 'O' ' ' 'O' ' ']
#  [' ' 'X' 'X' 'X' ' ' 'X' ' ']
#  [' ' 'X' 'O' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'X' 'X' ' ' 'X' ' ']
#  [' ' 'X' 'O' 'O' ' ' 'O' ' ']
#  [' ' 'O' 'X' 'X' 'X' 'X' ' ']]
# Episode 124/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' 'O' 'O' ' ']
#  ['O' 'O' 'X' ' ' 'X' 'X' ' ']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' 'X' 'O' 'O' 'X']]
# Episode 125/1000 - Epsilon: 0.0100
# [[' ' 'O' 'O' 'O' ' ' 'O' ' ']
#  [' ' 'X' 'X' 'X' 'X' 'X' ' ']
#  [' ' 'X' 'X' 'O' 'O' 'O' ' ']
#  [' ' 'O' 'O' 'X' 'X' 'X' ' ']
#  ['O' 'X' 'X' 'O' 'O' 'O' ' ']
#  ['X' 'O' 'O' 'X' 'X' 'X' ' ']]
# Episode 126/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'X' 'X' 'X' 'X' 'O']
#  ['X' 'X' 'O' 'O' 'O' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'X']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']]
# Episode 127/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'X' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 128/1000 - Epsilon: 0.0100
# [['O' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'O' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'O' 'O' 'O' 'X' 'O' 'O']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'X' 'O']]
# Episode 129/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'X' 'O' 'O' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 130/1000 - Epsilon: 0.0100
# [['O' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'O' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'O' 'O' 'O' 'X' 'O' 'O']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'X' 'O']]
# Episode 131/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 132/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 133/1000 - Epsilon: 0.0100
# [[' ' 'X' 'O' ' ' 'X' 'O' ' ']
#  [' ' 'O' 'X' ' ' 'O' 'X' ' ']
#  ['O' 'X' 'X' ' ' 'X' 'O' ' ']
#  ['X' 'O' 'O' ' ' 'O' 'X' ' ']
#  ['O' 'X' 'X' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']]
# Episode 134/1000 - Epsilon: 0.0100
# [[' ' 'O' 'O' ' ' ' ' ' ' ' ']
#  [' ' 'X' 'X' ' ' ' ' ' ' ' ']
#  [' ' 'X' 'X' ' ' 'X' ' ' ' ']
#  [' ' 'O' 'O' 'X' 'O' ' ' ' ']
#  ['O' 'X' 'O' 'O' 'X' ' ' ' ']
#  ['O' 'O' 'X' 'X' 'X' ' ' ' ']]
# Episode 135/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 136/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 137/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 138/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 139/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 140/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 141/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 142/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'X' 'X']]
# Episode 143/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' ' ' ' ' 'X']
#  ['O' 'X' 'O' ' ' 'O' ' ' 'O']
#  ['X' 'O' 'X' ' ' 'X' ' ' 'O']
#  ['O' 'O' 'O' ' ' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'O']
#  ['O' 'O' 'X' 'O' 'O' ' ' 'X']]
# Episode 144/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 145/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 146/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' ' ' ' ' 'O']
#  ['O' 'X' 'O' ' ' ' ' ' ' 'X']
#  ['X' 'O' 'X' ' ' 'X' ' ' 'O']
#  ['O' 'O' 'O' ' ' 'O' ' ' 'X']
#  ['X' 'X' 'X' 'X' 'X' ' ' 'O']
#  ['O' 'O' 'X' 'O' 'O' 'X' 'X']]
# Episode 147/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 148/1000 - Epsilon: 0.0100
# [['O' ' ' 'X' ' ' 'O' ' ' 'O']
#  ['X' ' ' 'O' ' ' 'X' ' ' 'X']
#  ['O' ' ' 'X' ' ' 'O' ' ' 'O']
#  ['O' 'O' 'O' ' ' 'X' ' ' 'X']
#  ['X' 'X' 'X' ' ' 'O' ' ' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 149/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'X' 'O']]
# Episode 150/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'X' 'O']]
# Episode 151/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'X' 'O']]
# Episode 152/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'X' 'O']]
# Episode 153/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 154/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 155/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' 'O' 'X' 'X' 'X']
#  ['O' ' ' 'O' 'X' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'O' 'O']]
# Episode 156/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'X' 'O' 'O']]
# Episode 157/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' ' ' 'O' 'X']
#  ['O' ' ' 'O' ' ' ' ' 'X' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'O' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'O']]
# Episode 158/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 159/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' 'O' 'X' 'X' 'X']
#  ['O' ' ' 'O' 'X' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'O' 'O']]
# Episode 160/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'O' 'O']]
# Episode 161/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'O' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'O' 'O']]
# Episode 162/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['O' ' ' 'O' ' ' ' ' 'O' 'O']
#  ['O' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['X' ' ' 'O' ' ' ' ' 'O' 'O']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 163/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 164/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 165/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 166/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 167/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 168/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 169/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 170/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 171/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 172/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 173/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'O' 'O']]
# Episode 174/1000 - Epsilon: 0.0100
# [[' ' 'X' 'X' ' ' ' ' ' ' ' ']
#  ['X' 'O' 'O' ' ' ' ' ' ' ' ']
#  ['O' 'O' 'X' ' ' ' ' ' ' ' ']
#  ['X' 'X' 'O' ' ' ' ' ' ' 'X']
#  ['O' 'O' 'O' 'O' ' ' ' ' 'O']
#  ['X' 'X' 'X' 'O' ' ' ' ' 'X']]
# Episode 175/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 176/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 177/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' ' ' 'O' ' ' 'O' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'O' 'O' 'O' 'O']]
# Episode 178/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'X' 'X' 'O' 'X' 'X' 'X']]
# Episode 179/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'O' 'X' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'X' 'O' 'O']]
# Episode 180/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 181/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 182/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 183/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['O' 'X' 'O' ' ' ' ' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 184/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'O' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'O']]
# Episode 185/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['O' 'X' 'O' ' ' ' ' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 186/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 187/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['O' 'X' 'O' ' ' ' ' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 188/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'O' 'O']]
# Episode 189/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' ' ' ' ']
#  [' ' 'X' ' ' 'X' ' ' ' ' ' ']
#  [' ' 'O' 'O' 'O' ' ' ' ' ' ']
#  [' ' 'X' 'X' 'X' 'X' ' ' ' ']
#  [' ' 'X' 'O' 'O' 'O' ' ' 'O']
#  [' ' 'O' 'X' 'X' 'X' ' ' 'X']]
# Episode 190/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' ' ' ' ']
#  [' ' 'X' ' ' 'X' ' ' ' ' ' ']
#  [' ' 'O' 'O' 'O' 'O' ' ' ' ']
#  [' ' 'X' 'X' 'X' 'O' ' ' 'X']
#  [' ' 'X' 'O' 'O' 'X' ' ' 'O']
#  [' ' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 191/1000 - Epsilon: 0.0100
# [[' ' 'O' 'X' 'O' ' ' 'O' 'O']
#  [' ' 'X' 'O' 'X' ' ' 'X' 'X']
#  [' ' 'O' 'O' 'O' ' ' 'O' 'O']
#  [' ' 'X' 'X' 'X' 'X' 'O' 'X']
#  ['X' 'X' 'O' 'O' 'X' 'X' 'O']
#  ['X' 'O' 'X' 'X' 'O' 'O' 'X']]
# Episode 192/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' ' ' ' ']
#  [' ' 'X' ' ' 'X' ' ' ' ' ' ']
#  [' ' 'O' 'O' 'O' ' ' ' ' ' ']
#  [' ' 'X' 'X' 'X' 'X' ' ' ' ']
#  [' ' 'X' 'O' 'O' 'O' ' ' 'O']
#  [' ' 'O' 'X' 'X' 'X' ' ' 'X']]
# Episode 193/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' ' ' ' ']
#  [' ' 'X' ' ' 'X' ' ' ' ' ' ']
#  [' ' 'O' 'O' 'O' ' ' ' ' ' ']
#  [' ' 'X' 'X' 'X' 'X' ' ' ' ']
#  [' ' 'X' 'O' 'O' 'O' ' ' 'O']
#  [' ' 'O' 'X' 'X' 'X' ' ' 'X']]
# Episode 194/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' ' ' ' ']
#  [' ' 'X' ' ' 'X' ' ' ' ' ' ']
#  [' ' 'O' 'O' 'O' ' ' ' ' ' ']
#  [' ' 'X' 'X' 'X' 'X' ' ' ' ']
#  [' ' 'X' 'O' 'O' 'O' ' ' 'O']
#  [' ' 'O' 'X' 'X' 'X' ' ' 'X']]
# Episode 195/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' ' ' 'X' 'O']
#  ['O' 'O' 'O' ' ' ' ' 'O' 'X']
#  ['X' 'X' 'X' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'O' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'X' 'O' 'O' 'O' 'O' 'X']]
# Episode 196/1000 - Epsilon: 0.0100
# [[' ' 'X' 'O' ' ' ' ' ' ' 'X']
#  [' ' 'O' 'X' ' ' ' ' ' ' 'X']
#  [' ' 'X' 'O' ' ' ' ' ' ' 'O']
#  ['X' 'O' 'X' 'O' ' ' ' ' 'X']
#  ['O' 'O' 'O' 'X' ' ' ' ' 'X']
#  ['X' 'X' 'O' 'O' 'O' 'O' 'X']]
# Episode 197/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'O']
#  ['O' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['X' 'X' 'O' 'X' 'X' 'X' 'X']]
# Episode 198/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['O' ' ' 'O' ' ' ' ' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'O' 'O' 'O' 'O']]
# Episode 199/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' 'O' ' ' 'X' 'X']
#  ['O' 'X' 'X' 'X' ' ' 'O' 'O']
#  ['X' 'O' 'O' 'O' ' ' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'X' 'O' 'O']
#  ['X' 'X' 'O' 'O' 'O' 'X' 'X']
#  ['O' 'O' 'X' 'O' 'X' 'O' 'X']]
# Episode 200/1000 - Epsilon: 0.0100
# [[' ' 'O' 'O' ' ' ' ' 'X' 'X']
#  [' ' 'X' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'O' 'X']]
# Episode 201/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' 'O' ' ' 'O' 'X']
#  ['O' 'X' 'X' 'X' 'X' 'X' 'O']
#  ['X' 'X' 'O' 'O' 'O' 'X' 'X']
#  ['X' 'O' 'X' 'X' 'X' 'O' 'O']
#  ['O' 'X' 'O' 'O' 'O' 'X' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'O' 'X']]
# Episode 202/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' ' ' 'X' 'X']
#  ['O' 'X' 'X' ' ' ' ' 'O' 'O']
#  ['X' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['O' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'X' 'O' 'X' ' ' 'X' 'X']
#  ['X' 'O' 'X' 'O' 'X' 'O' 'O']]
# Episode 203/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 204/1000 - Epsilon: 0.0100
# [[' ' 'O' 'O' ' ' ' ' 'X' 'X']
#  [' ' 'X' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'O' 'X']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'O']
#  ['X' 'O' 'X' 'O' 'O' 'O' 'X']]
# Episode 205/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'O' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']]
# Episode 206/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 207/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['O' ' ' 'O' ' ' ' ' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 208/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['O' ' ' 'O' ' ' ' ' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 209/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['O' ' ' 'O' ' ' ' ' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 210/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['O' ' ' 'O' ' ' ' ' 'O' 'O']
#  ['X' ' ' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'X' 'O' 'X' 'O' 'O' 'O']]
# Episode 211/1000 - Epsilon: 0.0100
# [['O' ' ' 'X' ' ' ' ' 'X' 'X']
#  ['X' 'X' 'O' ' ' ' ' 'O' 'O']
#  ['O' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' 'O' ' ' 'O' 'O']]
# Episode 212/1000 - Epsilon: 0.0100
# [['O' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['X' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['O' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'X']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 213/1000 - Epsilon: 0.0100
# [['O' 'X' 'O' ' ' ' ' 'X' 'O']
#  ['X' 'O' 'X' ' ' ' ' 'O' 'X']
#  ['O' 'O' 'O' ' ' ' ' 'X' 'O']
#  ['X' 'X' 'X' 'X' ' ' 'O' 'X']
#  ['O' 'X' 'O' 'O' 'X' 'X' 'O']
#  ['X' 'O' 'X' 'X' 'O' 'O' 'X']]
# Episode 214/1000 - Epsilon: 0.0100
# [['O' 'O' 'X' 'O' 'O' 'O' 'X']
#  ['X' 'X' 'O' 'X' 'X' 'X' 'O']
#  ['O' 'O' 'X' 'O' 'O' 'X' 'X']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']
#  ['O' 'X' 'O' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 215/1000 - Epsilon: 0.0100
# [['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'O' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'X' 'X' 'O' ' ' 'O' 'O']
#  ['O' 'X' 'O' 'X' ' ' 'O' 'X']
#  ['X' 'O' 'X' 'O' 'O' 'X' 'X']]
# Episode 216/1000 - Epsilon: 0.0100
# [['X' ' ' 'X' 'X' ' ' 'X' 'X']
#  ['O' 'O' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'O' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'X' 'O' 'O' ' ' 'O' 'O']
#  ['O' 'X' 'X' 'X' ' ' 'X' 'X']
#  ['X' 'O' 'O' 'X' 'O' 'O' 'O']]
# Episode 217/1000 - Epsilon: 0.0100
# [['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' ' ' 'O' 'O']
#  ['O' 'O' 'O' ' ' ' ' 'X' 'X']
# ...
# Episode 929/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 930/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 931/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 932/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 933/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 934/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'X' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'O' 'X' 'O' 'X' 'O']]
# Episode 935/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 936/1000 - Epsilon: 0.0100
# [['O' 'X' 'O' 'O' ' ' 'X' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'O' 'O']
#  ['O' 'X' 'O' 'O' ' ' 'X' 'X']
#  ['X' 'O' 'X' 'X' ' ' 'X' 'O']
#  ['O' 'X' 'O' 'O' 'O' 'O' 'X']
#  ['X' 'O' 'O' 'X' 'X' 'X' 'O']]
# Episode 937/1000 - Epsilon: 0.0100
# [['O' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['X' 'X' 'O' ' ' ' ' 'O' 'O']
#  ['O' 'O' 'X' ' ' ' ' 'X' 'X']
#  ['X' 'X' 'O' ' ' ' ' 'X' 'O']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' 'X' 'O' 'X' 'O']]
# Episode 938/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' 'O' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'X' 'O']]
# Episode 939/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 940/1000 - Epsilon: 0.0100
# [['O' 'X' ' ' ' ' ' ' 'X' 'X']
#  ['X' 'O' ' ' ' ' ' ' 'O' 'O']
#  ['O' 'X' ' ' ' ' ' ' 'X' 'X']
#  ['X' 'O' ' ' ' ' ' ' 'O' 'X']
#  ['X' 'X' ' ' ' ' ' ' 'X' 'O']
#  ['O' 'O' 'O' 'O' ' ' 'O' 'X']]
# Episode 941/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' 'O' ' ' 'O' 'X']
#  ['X' 'X' ' ' 'X' ' ' 'X' 'O']
#  ['O' 'O' ' ' 'O' ' ' 'O' 'X']
#  ['X' 'O' ' ' 'X' 'X' 'X' 'X']
#  ['O' 'X' ' ' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'X' 'X' 'O' 'X']]
# Episode 942/1000 - Epsilon: 0.0100
# [['X' 'X' ' ' ' ' ' ' 'X' 'X']
#  ['O' 'X' ' ' ' ' ' ' 'O' 'O']
#  ['X' 'O' ' ' ' ' ' ' 'X' 'X']
#  ['O' 'X' ' ' ' ' ' ' 'O' 'X']
#  ['X' 'O' ' ' ' ' ' ' 'X' 'O']
#  ['O' 'O' 'O' 'O' ' ' 'O' 'X']]
# Episode 943/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 944/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 945/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 946/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 947/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 948/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 949/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 950/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 951/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 952/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 953/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 954/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 955/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'X' 'O' 'O']
#  ['X' 'O' 'O' 'X' 'O' 'X' 'X']]
# Episode 956/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 957/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 958/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 959/1000 - Epsilon: 0.0100
# [['O' 'X' 'O' ' ' ' ' 'X' 'X']
#  ['X' 'O' 'X' ' ' 'X' 'O' 'O']
#  ['O' 'X' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'O' 'X' 'O' 'X']]
# Episode 960/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 961/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 962/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 963/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 964/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 965/1000 - Epsilon: 0.0100
# [['O' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['X' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 966/1000 - Epsilon: 0.0100
# [['X' 'X' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'O' 'X' 'X' 'O' 'X']]
# Episode 967/1000 - Epsilon: 0.0100
# [['O' 'O' ' ' 'O' 'O' 'X' 'X']
#  ['X' 'X' ' ' 'X' 'X' 'O' 'O']
#  ['O' 'O' ' ' 'O' 'O' 'X' 'X']
#  ['X' 'X' ' ' 'X' 'X' 'O' 'O']
#  ['O' 'O' ' ' 'O' 'O' 'X' 'X']
#  ['X' 'X' 'X' 'X' 'X' 'O' 'O']]
# Episode 968/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['O' 'O' 'X' 'X' 'X' 'O' 'X']]
# Episode 969/1000 - Epsilon: 0.0100
# [['O' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'O' 'O' 'X' 'O' 'O' 'O']
#  ['O' 'X' 'X' 'O' 'X' 'X' 'X']
#  ['X' 'O' 'O' 'X' 'O' 'O' 'X']
#  ['O' 'X' 'X' 'O' 'X' 'X' 'O']
#  ['O' 'O' 'O' 'X' 'O' 'O' 'X']]
# Episode 970/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 971/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 972/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 973/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' ' ' 'O' 'O' 'O']
#  [' ' 'X' ' ' ' ' 'X' 'O' 'X']
#  [' ' 'O' ' ' ' ' 'O' 'X' 'O']
#  [' ' 'X' ' ' ' ' 'X' 'X' 'X']
#  [' ' 'X' ' ' ' ' 'O' 'O' 'O']
#  [' ' 'O' ' ' 'X' 'X' 'X' 'X']]
# Episode 974/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 975/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' 'X' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'O' 'X' 'O' 'X']
#  ['O' 'O' 'X' 'O' 'O' 'X' 'O']]
# Episode 976/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 977/1000 - Epsilon: 0.0100
# [['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 978/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 979/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 980/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 981/1000 - Epsilon: 0.0100
# [['X' 'X' 'X' ' ' 'O' 'X' 'X']
#  ['O' 'O' 'O' ' ' 'X' 'O' 'O']
#  ['X' 'X' 'X' 'O' 'O' 'X' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'X' 'O']
#  ['X' 'O' 'X' 'O' 'O' 'O' 'X']
#  ['O' 'O' 'O' 'X' 'X' 'X' 'O']]
# Episode 982/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 983/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 984/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 985/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 986/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 987/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 988/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 989/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 990/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'O']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'O' 'X' 'O']]
# Episode 991/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 992/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 993/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 994/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 995/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'X' 'X' 'X' 'O']]
# Episode 996/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'O' ' ' 'X' 'X' 'X']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'O' 'O' 'O' 'O' 'X']
#  ['O' 'O' 'X' 'O' 'X' 'X' 'O']]
# Episode 997/1000 - Epsilon: 0.0100
# [['X' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'X' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'O' ' ' 'O' 'O' 'O']
#  ['O' 'X' 'X' ' ' 'X' 'X' 'X']
#  ['X' 'X' 'O' ' ' 'O' 'O' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'X' 'X']]
# Episode 998/1000 - Epsilon: 0.0100
# [[' ' 'O' ' ' ' ' 'O' 'X' 'O']
#  [' ' 'X' ' ' ' ' 'X' 'O' 'X']
#  [' ' 'O' ' ' ' ' 'O' 'X' 'O']
#  ['X' 'X' ' ' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'X' ' ' 'O' 'X' 'O']
#  ['X' 'O' 'O' 'O' 'X' 'X' 'X']]
# Episode 999/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['O' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['X' 'O' 'X' ' ' 'O' 'O' 'X']
#  ['X' 'X' 'O' ' ' 'X' 'X' 'O']
#  ['O' 'O' 'X' 'O' 'O' 'O' 'X']
#  ['X' 'O' 'X' 'O' 'X' 'O' 'X']]
# Episode 1000/1000 - Epsilon: 0.0100
# [['X' 'O' 'X' ' ' 'O' 'X' 'O']
#  ['O' 'X' 'O' ' ' 'X' 'O' 'X']
#  ['X' 'O' 'X' ' ' 'O' 'X' 'O']
#  ['X' 'X' 'O' ' ' 'X' 'O' 'X']
#  ['O' 'O' 'O' 'O' 'O' 'X' 'O']
#  ['X' 'O' 'X' 'X' 'X' 'O' 'X']]

# %%
agent
